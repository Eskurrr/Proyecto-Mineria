# %% [markdown]
# <a href="https://colab.research.google.com/github/Eskurrr/Proyecto-Mineria/blob/main/P1_MINERIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importamos el modulo drive y lo montamos a una ubicación dentro de la cuenta de drive montada

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importamos los modulos numpy y pandas para su uso pero los importamos con la abreviacion para su uso np y pd respectivamente

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# %% [markdown]
# Creamos la variable datos en la que utilizaremos la funcion read_csv de panda para leer el archivo Datos.csv de nuestro drive, quitaremos la columna 0 que esta de indice y especificaremos los tipos de varias columnas con dtype para que panda utilize el tipo especifico String en lugar del general Object que es el utilizado por defecto al leer strings ya que contiene al tipo string, pero queremos que sean strings para el tratado de los datos

# %%
datos = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datos.csv', delimiter = ',', skiprows= 0, dtype={'Sex': 'string','ChestPainType': 'string','RestingECG': 'string','ExerciseAngina': 'string','ST_Slope': 'string'})

datos
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %% [markdown]
# Revisamos la correcta conversion a string de las columnas especificadas y de las demas columnas a tipos tratables

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    string
#  2   ChestPainType   918 non-null    string
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    string
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    string
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    string
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), string(5)
# memory usage: 86.2 KB

# %% [markdown]
# Revisamos si el DataFrame contiene duplicados llamando al metodo sum en datos.duplicated y guardando el resultado en una variable para despues imprimir el resultado

# %%
num_duplicates = datos.duplicated().sum()
print(f"El número de filas duplicadas en el DataFrame es: {num_duplicates}")
# Out:
# El número de filas duplicadas en el DataFrame es: 0

# %% [markdown]
# Por si acaso llamamos al metodo drop_duplicates() que borra cualquier fila duplicada del dataframe

# %%
datos.drop_duplicates()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %% [markdown]
# Creamos un nuevo DataFrame donde vamos a ordenar los valores por la columna de edad en orden descendiente con sort_values(by = ['Age'])

# %%
datos_sorted = datos.sort_values(by = ['Age'])
datos_sorted
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 208   28   M           ATA        130          132          0        LVH
# 829   29   M           ATA        130          204          0        LVH
# 170   29   M           ATA        120          243          0     Normal
# 219   29   M           ATA        140          263          0     Normal
# 215   30   F            TA        170          237          0         ST
# ..   ...  ..           ...        ...          ...        ...        ...
# 556   75   M           ASY        160          310          1     Normal
# 688   76   F           NAP        140          197          0         ST
# 541   76   M           NAP        104          113          0        LVH
# 814   77   M           ASY        125          304          0        LVH
# 447   77   M           ASY        124          171          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 208    185              N      0.0       Up             0
# 829    202              N      0.0       Up             0
# 170    160              N      0.0       Up             0
# 219    170              N      0.0       Up             0
# 215    170              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 556    112              Y      2.0     Down             0
# 688    116              N      1.1     Flat             0
# 541    120              N      3.5     Down             1
# 814    162              Y      0.0       Up             1
# 447    110              Y      2.0       Up             1
#
# [918 rows x 12 columns]

# %% [markdown]
# Como en datos.info() hemos podido observar que no tenemos valores nulos, vamos a crearlos artificialmente borrando datos aleatoriamente de la columna de Cholesterol que terminen en 3

# %%
conteo = (datos['Cholesterol'] % 10 == 3).sum()
print("Cantidad de valores que terminan en 3:", conteo)
# Out:
# Cantidad de valores que terminan en 3: 83

# %% [markdown]
# Ahora que sabemos que 83 filas contienen un dato Cholesterol que termina en 3 vamos a proceder a aplicar una funcion a toda la columna para que los borre

# %%
datos_sorted['Cholesterol'] = datos_sorted['Cholesterol'].apply(lambda x: np.nan if x % 10 == 3 else x)
datos_sorted.loc[datos_sorted['Cholesterol'].isnull()]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 170   29   M           ATA        120          NaN          0     Normal
# 219   29   M           ATA        140          NaN          0     Normal
# 839   35   F           ASY        138          NaN          0     Normal
# 46    37   M           ASY        120          NaN          0     Normal
# 229   37   F           ASY        130          NaN          0         ST
# ..   ...  ..           ...        ...          ...        ...        ...
# 689   67   F           ASY        106          NaN          0     Normal
# 914   68   M           ASY        144          NaN          1     Normal
# 573   72   M           ASY        160          NaN          1        LVH
# 491   75   M           ASY        170          NaN          1         ST
# 541   76   M           NAP        104          NaN          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 170    160              N      0.0       Up             0
# 219    170              N      0.0       Up             0
# 839    182              N      1.4       Up             0
# 46     168              N      0.0       Up             0
# 229    184              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 689    142              N      0.3       Up             0
# 914    141              N      3.4     Flat             1
# 573    130              N      1.5     Flat             1
# 491    108              N      0.0     Flat             1
# 541    120              N      3.5     Down             1
#
# [83 rows x 12 columns]

# %% [markdown]
# Ahora tratamos esos datos nulos que hemos creado rellenandolos con 0

# %%
datos_sorted.fillna(0, inplace=True)
datos_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 918 entries, 208 to 447
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    string
#  2   ChestPainType   918 non-null    string
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    float64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    string
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    string
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    string
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(2), int64(5), string(5)
# memory usage: 93.2 KB

# %% [markdown]
# Vamos a crear una nueva columna "CardioRisk" basandonos en el riesgo cardiaco calculado de cada fila sumando 5 tipicos indicadores de riesgo cardiaco con un 1 si esta fuera de los valores normales y 0 si esta dentro del rango normal

# %%
datos_sorted['CardioRisk'] = (datos_sorted['RestingBP'] > 130).astype(int) + \
                   (datos_sorted['Cholesterol'] > 200).astype(int) + \
                   datos_sorted['FastingBS'] + \
                   (datos_sorted['Oldpeak'] > 2).astype(int) + \
                   (datos_sorted['ExerciseAngina'] == 'Y').astype(int)
datos_sorted
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 208   28   M           ATA        130        132.0          0        LVH
# 829   29   M           ATA        130        204.0          0        LVH
# 170   29   M           ATA        120          0.0          0     Normal
# 219   29   M           ATA        140          0.0          0     Normal
# 215   30   F            TA        170        237.0          0         ST
# ..   ...  ..           ...        ...          ...        ...        ...
# 556   75   M           ASY        160        310.0          1     Normal
# 688   76   F           NAP        140        197.0          0         ST
# 541   76   M           NAP        104          0.0          0        LVH
# 814   77   M           ASY        125        304.0          0        LVH
# 447   77   M           ASY        124        171.0          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  CardioRisk
# 208    185              N      0.0       Up             0           0
# 829    202              N      0.0       Up             0           1
# 170    160              N      0.0       Up             0           0
# 219    170              N      0.0       Up             0           1
# 215    170              N      0.0       Up             0           2
# ..     ...            ...      ...      ...           ...         ...
# 556    112              Y      2.0     Down             0           4
# 688    116              N      1.1     Flat             0           1
# 541    120              N      3.5     Down             1           1
# 814    162              Y      0.0       Up             1           2
# 447    110              Y      2.0       Up             1           1
#
# [918 rows x 13 columns]

# %% [markdown]
# Para la normalizacion primero tenemos que ver si tenemos valores atipicos para decidir si utilizar un minmaxscaler o un robustscaler ya que si normalizamos solo basandonos en minimos y maximos somos sensibles a los valores atipicos, utilizamos la funcion describe para sacar datos estadisticos de cada columna y ver el resultado

# %%
datos_sorted.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   176.970588    0.233115  136.809368
# std      9.432617   18.514154   120.662820    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000     0.000000    0.000000  120.000000
# 50%     54.000000  130.000000   214.500000    0.000000  138.000000
# 75%     60.000000  140.000000   260.750000    0.000000  156.000000
# max     77.000000  200.000000   564.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease  CardioRisk
# count  918.000000    918.000000  918.000000
# mean     0.887364      0.553377    1.783224
# std      1.066570      0.497414    1.100145
# min     -2.600000      0.000000    0.000000
# 25%      0.000000      0.000000    1.000000
# 50%      0.600000      1.000000    2.000000
# 75%      1.500000      1.000000    3.000000
# max      6.200000      1.000000    5.000000

# %%
datos_normalizados = datos_sorted.copy()
robust_scaler = RobustScaler()
datos_normalizados[['Age','RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak','CardioRisk']] = robust_scaler.fit_transform(datos_sorted[['Age','RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak','CardioRisk']])
datos_normalizados
# Out:
#           Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 208 -2.000000   M           ATA       0.00    -0.316395          0        LVH
# 829 -1.923077   M           ATA       0.00    -0.040268          0        LVH
# 170 -1.923077   M           ATA      -0.50    -0.822627          0     Normal
# 219 -1.923077   M           ATA       0.50    -0.822627          0     Normal
# 215 -1.846154   F            TA       2.00     0.086290          0         ST
# ..        ...  ..           ...        ...          ...        ...        ...
# 556  1.615385   M           ASY       1.50     0.366251          1     Normal
# 688  1.692308   F           NAP       0.50    -0.067114          0         ST
# 541  1.692308   M           NAP      -1.30    -0.822627          0        LVH
# 814  1.769231   M           ASY      -0.25     0.343241          0        LVH
# 447  1.769231   M           ASY      -0.30    -0.166826          0         ST
#
#         MaxHR ExerciseAngina   Oldpeak ST_Slope  HeartDisease  CardioRisk
# 208  1.305556              N -0.400000       Up             0        -1.0
# 829  1.777778              N -0.400000       Up             0        -0.5
# 170  0.611111              N -0.400000       Up             0        -1.0
# 219  0.888889              N -0.400000       Up             0        -0.5
# 215  0.888889              N -0.400000       Up             0         0.0
# ..        ...            ...       ...      ...           ...         ...
# 556 -0.722222              Y  0.933333     Down             0         1.0
# 688 -0.611111              N  0.333333     Flat             0        -0.5
# 541 -0.500000              N  1.933333     Down             1        -0.5
# 814  0.666667              Y -0.400000       Up             1         0.0
# 447 -0.777778              Y  0.933333       Up             1        -0.5
#
# [918 rows x 13 columns]

# %%
datos_sorted['ChestPainType'].unique()
# Out:
# <StringArray>
# ['ATA', 'TA', 'ASY', 'NAP']
# Length: 4, dtype: string

# %%
ata = datos_normalizados['ChestPainType'].apply(lambda x : 1 if x == 'ATA'else 0 )
ata.rename('ATA', inplace=True)
asy = datos_normalizados['ChestPainType'].apply(lambda x : 1 if x == 'ASY'else 0 )
asy.rename('ASY', inplace=True)
nap = datos_normalizados['ChestPainType'].apply(lambda x : 1 if x == 'NAP'else 0 )
nap.rename('NAP', inplace=True)
ta = datos_normalizados['ChestPainType'].apply(lambda x : 1 if x == 'TA'else 0 )
ta.rename('TA', inplace=True)
datos_normalizados = pd.concat([datos_normalizados.iloc[:,:2], ata, asy, nap, ta, datos_normalizados.iloc[:,3:]], axis=1)
datos_normalizados
# Out:
#           Age Sex  ATA  ASY  NAP  TA  RestingBP  Cholesterol  FastingBS  \
# 208 -2.000000   M    1    0    0   0       0.00    -0.316395          0
# 829 -1.923077   M    1    0    0   0       0.00    -0.040268          0
# 170 -1.923077   M    1    0    0   0      -0.50    -0.822627          0
# 219 -1.923077   M    1    0    0   0       0.50    -0.822627          0
# 215 -1.846154   F    0    0    0   1       2.00     0.086290          0
# ..        ...  ..  ...  ...  ...  ..        ...          ...        ...
# 556  1.615385   M    0    1    0   0       1.50     0.366251          1
# 688  1.692308   F    0    0    1   0       0.50    -0.067114          0
# 541  1.692308   M    0    0    1   0      -1.30    -0.822627          0
# 814  1.769231   M    0    1    0   0      -0.25     0.343241          0
# 447  1.769231   M    0    1    0   0      -0.30    -0.166826          0
#
#     RestingECG     MaxHR ExerciseAngina   Oldpeak ST_Slope  HeartDisease  \
# 208        LVH  1.305556              N -0.400000       Up             0
# 829        LVH  1.777778              N -0.400000       Up             0
# 170     Normal  0.611111              N -0.400000       Up             0
# 219     Normal  0.888889              N -0.400000       Up             0
# 215         ST  0.888889              N -0.400000       Up             0
# ..         ...       ...            ...       ...      ...           ...
# 556     Normal -0.722222              Y  0.933333     Down             0
# 688         ST -0.611111              N  0.333333     Flat             0
# 541        LVH -0.500000              N  1.933333     Down             1
# 814        LVH  0.666667              Y -0.400000       Up             1
# 447         ST -0.777778              Y  0.933333       Up             1
#
#      CardioRisk
# 208        -1.0
# 829        -0.5
# 170        -1.0
# 219        -0.5
# 215         0.0
# ..          ...
# 556         1.0
# 688        -0.5
# 541        -0.5
# 814         0.0
# 447        -0.5
#
# [918 rows x 16 columns]

# %%
datos_sorted['Sex'].unique()
# Out:
# <StringArray>
# ['M', 'F']
# Length: 2, dtype: string

# %%
datos_normalizados['Sex'] = datos_normalizados['Sex'].apply(lambda x : 1 if x == 'M'else 0 )
datos_normalizados
# Out:
#           Age  Sex  ATA  ASY  NAP  TA  RestingBP  Cholesterol  FastingBS  \
# 208 -2.000000    1    1    0    0   0       0.00    -0.316395          0
# 829 -1.923077    1    1    0    0   0       0.00    -0.040268          0
# 170 -1.923077    1    1    0    0   0      -0.50    -0.822627          0
# 219 -1.923077    1    1    0    0   0       0.50    -0.822627          0
# 215 -1.846154    0    0    0    0   1       2.00     0.086290          0
# ..        ...  ...  ...  ...  ...  ..        ...          ...        ...
# 556  1.615385    1    0    1    0   0       1.50     0.366251          1
# 688  1.692308    0    0    0    1   0       0.50    -0.067114          0
# 541  1.692308    1    0    0    1   0      -1.30    -0.822627          0
# 814  1.769231    1    0    1    0   0      -0.25     0.343241          0
# 447  1.769231    1    0    1    0   0      -0.30    -0.166826          0
#
#     RestingECG     MaxHR ExerciseAngina   Oldpeak ST_Slope  HeartDisease  \
# 208        LVH  1.305556              N -0.400000       Up             0
# 829        LVH  1.777778              N -0.400000       Up             0
# 170     Normal  0.611111              N -0.400000       Up             0
# 219     Normal  0.888889              N -0.400000       Up             0
# 215         ST  0.888889              N -0.400000       Up             0
# ..         ...       ...            ...       ...      ...           ...
# 556     Normal -0.722222              Y  0.933333     Down             0
# 688         ST -0.611111              N  0.333333     Flat             0
# 541        LVH -0.500000              N  1.933333     Down             1
# 814        LVH  0.666667              Y -0.400000       Up             1
# 447         ST -0.777778              Y  0.933333       Up             1
#
#      CardioRisk
# 208        -1.0
# 829        -0.5
# 170        -1.0
# 219        -0.5
# 215         0.0
# ..          ...
# 556         1.0
# 688        -0.5
# 541        -0.5
# 814         0.0
# 447        -0.5
#
# [918 rows x 16 columns]

# %%
datos_sorted['ExerciseAngina'].unique()
# Out:
# <StringArray>
# ['N', 'Y']
# Length: 2, dtype: string

# %%
datos_normalizados['ExerciseAngina'] = datos_normalizados['ExerciseAngina'].apply(lambda x : 1 if x == 'Y' else 0 )
datos_normalizados
# Out:
#           Age  Sex  ATA  ASY  NAP  TA  RestingBP  Cholesterol  FastingBS  \
# 208 -2.000000    1    1    0    0   0       0.00    -0.316395          0
# 829 -1.923077    1    1    0    0   0       0.00    -0.040268          0
# 170 -1.923077    1    1    0    0   0      -0.50    -0.822627          0
# 219 -1.923077    1    1    0    0   0       0.50    -0.822627          0
# 215 -1.846154    0    0    0    0   1       2.00     0.086290          0
# ..        ...  ...  ...  ...  ...  ..        ...          ...        ...
# 556  1.615385    1    0    1    0   0       1.50     0.366251          1
# 688  1.692308    0    0    0    1   0       0.50    -0.067114          0
# 541  1.692308    1    0    0    1   0      -1.30    -0.822627          0
# 814  1.769231    1    0    1    0   0      -0.25     0.343241          0
# 447  1.769231    1    0    1    0   0      -0.30    -0.166826          0
#
#     RestingECG     MaxHR  ExerciseAngina   Oldpeak ST_Slope  HeartDisease  \
# 208        LVH  1.305556               0 -0.400000       Up             0
# 829        LVH  1.777778               0 -0.400000       Up             0
# 170     Normal  0.611111               0 -0.400000       Up             0
# 219     Normal  0.888889               0 -0.400000       Up             0
# 215         ST  0.888889               0 -0.400000       Up             0
# ..         ...       ...             ...       ...      ...           ...
# 556     Normal -0.722222               1  0.933333     Down             0
# 688         ST -0.611111               0  0.333333     Flat             0
# 541        LVH -0.500000               0  1.933333     Down             1
# 814        LVH  0.666667               1 -0.400000       Up             1
# 447         ST -0.777778               1  0.933333       Up             1
#
#      CardioRisk
# 208        -1.0
# 829        -0.5
# 170        -1.0
# 219        -0.5
# 215         0.0
# ..          ...
# 556         1.0
# 688        -0.5
# 541        -0.5
# 814         0.0
# 447        -0.5
#
# [918 rows x 16 columns]

# %%
datos_sorted['ST_Slope'].unique()
# Out:
# <StringArray>
# ['Up', 'Flat', 'Down']
# Length: 3, dtype: string

# %%
mapa = {'Up' : 1 , 'Flat':0.5 , 'Down':0}
datos_normalizados['ST_Slope'] = datos_normalizados['ST_Slope'].map(mapa)
datos_normalizados
# Out:
#           Age  Sex  ATA  ASY  NAP  TA  RestingBP  Cholesterol  FastingBS  \
# 208 -2.000000    1    1    0    0   0       0.00    -0.316395          0
# 829 -1.923077    1    1    0    0   0       0.00    -0.040268          0
# 170 -1.923077    1    1    0    0   0      -0.50    -0.822627          0
# 219 -1.923077    1    1    0    0   0       0.50    -0.822627          0
# 215 -1.846154    0    0    0    0   1       2.00     0.086290          0
# ..        ...  ...  ...  ...  ...  ..        ...          ...        ...
# 556  1.615385    1    0    1    0   0       1.50     0.366251          1
# 688  1.692308    0    0    0    1   0       0.50    -0.067114          0
# 541  1.692308    1    0    0    1   0      -1.30    -0.822627          0
# 814  1.769231    1    0    1    0   0      -0.25     0.343241          0
# 447  1.769231    1    0    1    0   0      -0.30    -0.166826          0
#
#     RestingECG     MaxHR  ExerciseAngina   Oldpeak  ST_Slope  HeartDisease  \
# 208        LVH  1.305556               0 -0.400000       1.0             0
# 829        LVH  1.777778               0 -0.400000       1.0             0
# 170     Normal  0.611111               0 -0.400000       1.0             0
# 219     Normal  0.888889               0 -0.400000       1.0             0
# 215         ST  0.888889               0 -0.400000       1.0             0
# ..         ...       ...             ...       ...       ...           ...
# 556     Normal -0.722222               1  0.933333       0.0             0
# 688         ST -0.611111               0  0.333333       0.5             0
# 541        LVH -0.500000               0  1.933333       0.0             1
# 814        LVH  0.666667               1 -0.400000       1.0             1
# 447         ST -0.777778               1  0.933333       1.0             1
#
#      CardioRisk
# 208        -1.0
# 829        -0.5
# 170        -1.0
# 219        -0.5
# 215         0.0
# ..          ...
# 556         1.0
# 688        -0.5
# 541        -0.5
# 814         0.0
# 447        -0.5
#
# [918 rows x 16 columns]

# %%
datos_normalizados['RestingECG'].unique()
# Out:
# <StringArray>
# ['LVH', 'Normal', 'ST']
# Length: 3, dtype: string

# %%
lvh = datos_normalizados['RestingECG'].apply(lambda x : 1 if x == 'LVH' else 0 )
lvh.rename('LVH', inplace=True)
normal = datos_normalizados['RestingECG'].apply(lambda x : 1 if x == 'Normal' else 0 )
normal.rename('Normal', inplace=True)
st = datos_normalizados['RestingECG'].apply(lambda x : 1 if x == 'ST' else 0 )
st.rename('ST', inplace=True)
datos_normalizados = pd.concat([datos_normalizados.iloc[:,:9], lvh, normal, st, datos_normalizados.iloc[:,10:]], axis=1)
datos_normalizados
# Out:
#           Age  Sex  ATA  ASY  NAP  TA  RestingBP  Cholesterol  FastingBS  LVH  \
# 208 -2.000000    1    1    0    0   0       0.00    -0.316395          0    1
# 829 -1.923077    1    1    0    0   0       0.00    -0.040268          0    1
# 170 -1.923077    1    1    0    0   0      -0.50    -0.822627          0    0
# 219 -1.923077    1    1    0    0   0       0.50    -0.822627          0    0
# 215 -1.846154    0    0    0    0   1       2.00     0.086290          0    0
# ..        ...  ...  ...  ...  ...  ..        ...          ...        ...  ...
# 556  1.615385    1    0    1    0   0       1.50     0.366251          1    0
# 688  1.692308    0    0    0    1   0       0.50    -0.067114          0    0
# 541  1.692308    1    0    0    1   0      -1.30    -0.822627          0    1
# 814  1.769231    1    0    1    0   0      -0.25     0.343241          0    1
# 447  1.769231    1    0    1    0   0      -0.30    -0.166826          0    0
#
#      Normal  ST     MaxHR  ExerciseAngina   Oldpeak  ST_Slope  HeartDisease  \
# 208       0   0  1.305556               0 -0.400000       1.0             0
# 829       0   0  1.777778               0 -0.400000       1.0             0
# 170       1   0  0.611111               0 -0.400000       1.0             0
# 219       1   0  0.888889               0 -0.400000       1.0             0
# 215       0   1  0.888889               0 -0.400000       1.0             0
# ..      ...  ..       ...             ...       ...       ...           ...
# 556       1   0 -0.722222               1  0.933333       0.0             0
# 688       0   1 -0.611111               0  0.333333       0.5             0
# 541       0   0 -0.500000               0  1.933333       0.0             1
# 814       0   0  0.666667               1 -0.400000       1.0             1
# 447       0   1 -0.777778               1  0.933333       1.0             1
#
#      CardioRisk
# 208        -1.0
# 829        -0.5
# 170        -1.0
# 219        -0.5
# 215         0.0
# ..          ...
# 556         1.0
# 688        -0.5
# 541        -0.5
# 814         0.0
# 447        -0.5
#
# [918 rows x 18 columns]

# %%
datos_normalizados.describe()
# Out:
#               Age         Sex         ATA         ASY         NAP          TA  \
# count  918.000000  918.000000  918.000000  918.000000  918.000000  918.000000
# mean    -0.037624    0.789760    0.188453    0.540305    0.221133    0.050109
# std      0.725586    0.407701    0.391287    0.498645    0.415236    0.218289
# min     -2.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     -0.538462    1.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 75%      0.461538    1.000000    0.000000    1.000000    0.000000    0.000000
# max      1.769231    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         RestingBP  Cholesterol   FastingBS         LVH      Normal  \
# count  918.000000   918.000000  918.000000  918.000000  918.000000
# mean     0.119826    -0.143929    0.233115    0.204793    0.601307
# std      0.925708     0.462753    0.423046    0.403770    0.489896
# min     -6.500000    -0.822627    0.000000    0.000000    0.000000
# 25%     -0.500000    -0.822627    0.000000    0.000000    0.000000
# 50%      0.000000     0.000000    0.000000    0.000000    1.000000
# 75%      0.500000     0.177373    0.000000    0.000000    1.000000
# max      3.500000     1.340364    1.000000    1.000000    1.000000
#
#                ST       MaxHR  ExerciseAngina     Oldpeak    ST_Slope  \
# count  918.000000  918.000000      918.000000  918.000000  918.000000
# mean     0.193900   -0.033073        0.404139    0.191576    0.680828
# std      0.395567    0.707232        0.490992    0.711047    0.303528
# min      0.000000   -2.166667        0.000000   -2.133333    0.000000
# 25%      0.000000   -0.500000        0.000000   -0.400000    0.500000
# 50%      0.000000    0.000000        0.000000    0.000000    0.500000
# 75%      0.000000    0.500000        1.000000    0.600000    1.000000
# max      1.000000    1.777778        1.000000    3.733333    1.000000
#
#        HeartDisease  CardioRisk
# count    918.000000  918.000000
# mean       0.553377   -0.108388
# std        0.497414    0.550072
# min        0.000000   -1.000000
# 25%        0.000000   -0.500000
# 50%        1.000000    0.000000
# 75%        1.000000    0.500000
# max        1.000000    1.500000
